# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table

import Magnaplot

# %matplotlib notebook

zdi_data = Table.read("../zdi_data/MasterTable_ZDI.csv",format='csv')

# %%
zdi_data
# Out:
# <Table length=37>
#   Star Name    Mass(Msun) Prot(d)    Ro   ...   Dip.    Qua.    Oct.   Axisym
#     str14       float64   float64 float64 ... float64 float64 float64 float64
# -------------- ---------- ------- ------- ... ------- ------- ------- -------
#    GJ 182 (07)       0.75    4.35   0.174 ...    0.48    0.18    0.14    0.17
#    DT Vir (07)       0.59    2.85   0.092 ...    0.64    0.17    0.08    0.12
#    DT Vir (08)       0.59    2.85   0.092 ...     0.1    0.17    0.17     0.2
#    DS Leo (07)       0.58    14.0   0.438 ...    0.52    0.37    0.08    0.58
#    DS Leo (08)       0.58    14.0   0.438 ...    0.52    0.31    0.07    0.16
#     GJ 49 (07)       0.57    18.6   0.564 ...    0.71     0.2    0.07    0.67
#    OT Ser (07)       0.55     3.4   0.097 ...    0.47    0.19    0.18    0.86
#    OT Ser (08)       0.55     3.4   0.097 ...    0.33    0.17    0.21    0.66
#    CE Boo (08)       0.48    14.7    0.35 ...    0.87    0.06    0.03    0.96
#    EV Lac (06)       0.32    4.38   0.068 ...     0.6    0.13    0.03    0.36
#            ...        ...     ...     ... ...     ...     ...     ...     ...
# GJ 1245 B (08)       0.12    0.71   0.007 ...    0.33    0.25    0.19     0.2
#    WX UMa (06)        0.1    0.78   0.008 ...    0.66    0.21    0.06    0.92
#    WX UMa (07)        0.1    0.78   0.008 ...    0.71    0.13    0.03    0.92
#    WX UMa (08)        0.1    0.78   0.008 ...    0.69    0.19    0.06    0.83
#    WX UMa (09)        0.1    0.78   0.008 ...    0.89    0.02    0.02    0.95
#    DX Cnc (07)        0.1    0.46   0.005 ...    0.69    0.11    0.09    0.77
#    DX Cnc (08)        0.1    0.46   0.005 ...    0.31    0.25     0.1    0.49
#    DX Cnc (09)        0.1    0.46   0.005 ...    0.42    0.11    0.04     0.7
#   GJ 3622 (08)       0.09     1.5   0.015 ...     0.9    0.07     nan    0.73
#   GJ 3622 (09)       0.09     1.5   0.015 ...    0.84    0.09     nan     0.8

# %%
#Example plot
plt.scatter(np.log10(zdi_data[2][:]),[zdi_data[1][:]])
plt.xlabel("log Period (d)")
plt.ylabel("Mass (Msun)")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'Mass (Msun)')

# %%
mass = zdi_data[1][:]
period = zdi_data[2][:]
rossby = zdi_data[3][:]
B2 = zdi_data[6][:]
Bfield = zdi_data[7][:]
poloidal = zdi_data[8][:]
dipole = zdi_data[9][:]
quad = zdi_data[10][:]
octo = zdi_data[11][:]
axisym = zdi_data[12][:]

# %%
#MagnaPlot(xin,yin,colin,areain,symbin)
Magnaplot.MagnaPlot(np.log10(period),mass,poloidal,B2,axisym,file='confuso.pdf',
                    xlabel="$\log_{10}$ Period (d)",xlims=[-0.5,1.5])
# Out:
# <img src="data:image/png;base64,..." width="722">
# (<Figure size 276x207 with 3 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1144acd68>)
